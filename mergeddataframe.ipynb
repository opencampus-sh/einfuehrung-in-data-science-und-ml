# %%
import pandas as pd

# %%
df1 = pd.read_csv('kiwo.csv')
df2 = pd.read_csv('umsatzdaten_gekuerzt.csv')
df3 = pd.read_csv('wetter.csv')

merged_df = pd.concat([df1, df2, df3], ignore_index=True)

merged_df.to_csv('merged_data.csv', index=False)

# %%
merged_df = pd.read_csv('merged_data.csv')

print(merged_df.head())
print(merged_df.info())
print(merged_df.sample(n=10))

print(merged_df.isnull().sum())
# Out:
#         Datum  KielerWoche  Warengruppe  Umsatz  Bewoelkung  Temperatur  \
# 0  2012-06-16          1.0          NaN     NaN         NaN         NaN
# 1  2012-06-17          1.0          NaN     NaN         NaN         NaN
# 2  2012-06-18          1.0          NaN     NaN         NaN         NaN
# 3  2012-06-19          1.0          NaN     NaN         NaN         NaN
# 4  2012-06-20          1.0          NaN     NaN         NaN         NaN
#
#    Windgeschwindigkeit  Wettercode
# 0                  NaN         NaN
# 1                  NaN         NaN
# 2                  NaN         NaN
# 3                  NaN         NaN
# 4                  NaN         NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12007 entries, 0 to 12006
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Datum                12007 non-null  object
#  1   KielerWoche          72 non-null     float64
# ...

# %%
import numpy as np

# %%
print (df.describe(merged_df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print (df.describe(merged_df))
#
# NameError: name 'df' is not defined

# %%
print(merged_df.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(merged_df.describe())
#
# NameError: name 'merged_df' is not defined

# %%
print(merged_df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(merged_df.head())
#
# NameError: name 'merged_df' is not defined

# %%
merged_df = pd.read_csv('merged_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 merged_df = pd.read_csv('merged_data.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
merged_df = pd.read_csv('merged_data.csv')

# %%
print(merged_df.describe())
# Out:
#        KielerWoche  Warengruppe       Umsatz   Bewoelkung   Temperatur  \
# count         72.0  9334.000000  9334.000000  2591.000000  2601.000000
# mean           1.0     3.088172   206.749044     4.805866    12.099586
# std            0.0     1.489002   144.545189     2.578299     7.174357
# min            1.0     1.000000     7.051201     0.000000   -10.250000
# 25%            1.0     2.000000    96.897441     3.000000     6.512500
# 50%            1.0     3.000000   161.900831     6.000000    12.000000
# 75%            1.0     4.000000   280.644663     7.000000    17.825000
# max            1.0     6.000000  1879.461831     8.000000    32.671428
#
#        Windgeschwindigkeit   Wettercode
# count          2601.000000  1932.000000
# mean             11.191080    37.484472
# std               4.124693    27.567144
# min               3.000000     0.000000
# 25%               8.000000    10.000000
# 50%              10.000000    28.000000
# 75%              14.000000    61.000000
# ...

# %%
import matplotlib.pyplot as plt

# Histogramme für alle numerischen Spalten
merged_df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# Boxplots für alle numerischen Spalten
merged_df.boxplot(figsize=(10, 6))
plt.tight_layout()
plt.show()
